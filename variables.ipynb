# %%
a=12
b=56.66
c='datascience'
print(a)
print(b)
print(c)
# Out:
# 12
# 56.66
# datascience

# %%
10a=100
# Out:
#   File "/tmp/ipython-input-3011662828.py", line 1
#     10a=100
#      ^
# SyntaxError: invalid decimal literal

# %%
_10a=100
print(_10a)
# Out:
# 100

# %%
a_b=100
print(a_b)
# Out:
# 100

# %%
sai_kumar=10
print(sai_kumar)
print(10)
print('sai kumar')
# Out:
# 10
# 10
# sai kumar

# %%
city='hyd'
print(city)
# Out:
# hyd

# %%
city='hyd'
print(CITY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1572817809.py in <cell line: 0>()
#       1 city='hyd'
# ----> 2 print(CITY)
#
# NameError: name 'CITY' is not defined
