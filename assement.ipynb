# %%
a=12
b=14
print(a+b)
print(a-b)
print(a*b)
# Out:
# 26
# -2
# 168

# %%
Write a program to check whether a given number is even or odd using the modulus (%) operator.

# %%
n=int(input("enter a number:"))
rem = n % 2
if rem==0:
  print(n, 'is even')
else:
  print(n, 'is odd')
# Out:
# enter a number:34
# 34 is even

# %%
Accept an integer from the user and print:
Square of the number
Cube of the number

# %%
num=int(input("enter a values"))
a=num*num
b=num*num*num
print('square of the number:',a)
print('cube of the number:',b)
# Out:
# enter a values3
# square of the number: 9
# cube of the number: 27

# %%
Compare two numbers entered by the user and print:
Whether they are equal
Which one is greater

# %%
n1=int(input('enter the first number:'))
n2=int(input('enter the second number:'))
if n1==n2:
  print('both are same')
elif n1>n2:
  print(n1,'is greater then',n2)
else:
  print(n2,'is greater then',n1)
# Out:
# enter the first number:45
# enter the second number:45
# both are same

# %%
Write a program to check if a number lies between 10 and 50 (inclusive) using logical operators (and, or).

# %%
a=int(input("enter a number:"))
if a>=10 and a<=50:
  print(a,"lies between 10 and 50")
else:
  print(a,"does not lies between 10 and 50")
# Out:
# enter a number:78
# 78 does not lies between 10 and 50

# %%
Swap values of two variables without using a third variable.

# %%
a=23
b=34
a,b=b,a
print(a)
print(b)
# Out:
# 34
# 23

# %%
Take a string from the user and check if it contains the character 'a'.

# %%
s=input('enter a string')
if 'a' in s:
  print("The string contians 'a'")
else:
  print("The does not string contians 'a'")
# Out:
# enter a string'hari'
# The string contians 'a'

# %%
Write a program to check whether a given number is both divisible by 3 and 5.

# %%
n=int(input("enter a number:"))
if n%3==0 and n%5==0:
  print(n,"is divisible by both 3 and 5")
else:
  print(n,"is not divisible by both 3 and 5")
# Out:
# enter a number:15
# 15 is divisible by both 3 and 5

# %%
Write a program that accepts three numbers and prints the largest using comparison and logical operators.

# %%
a=12
b=45
c=34
if a>b or a>c:
  print(a,"is the largest:")
elif b>a and b>c:
  print(b,"is the largest:")
else:
  print(c,"is the largest:")
# Out:
# 45 is the largest:

# %%
r = float(input("Enter the radius of the circle: "))

area = 3.14 * (r ** 2)

print("Area of the circle =", area)
# Out:
# Enter the radius of the circle: 78
# Area of the circle = 19103.760000000002

# %%
Write a program to check if a number is positive, negative, or zero using

# %%
n=float(input("enter a number:"))
if n>0:
  print("The number is positive")
elif n<0:
  print("The number is negative")
else:
  print("The number is zero")
# Out:
# enter a number:56
# The number is positive

# %%
Input a number and check if it is a multiple of either 4 or 6

# %%
n=int(input("enter the number:"))
if n%4==0 and n%6==0:
  print(n,"is multiple by both 4 and 6")
else:
  print(n,"is not multiple by both 4 and 6")
# Out:
# enter the number:48
# 48 is multiple by both 4 and 6
