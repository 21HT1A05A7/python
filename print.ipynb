# %%
a=12
b=23.4
print(a)
print(b)
# Out:
# 12
# 23.4

# %%
a=150
print(a)
print(id(a))
# Out:
# 150
# 11659144

# %%
a=22
print('my name ia hari and my age is',a)
# Out:
# my name ia hari and my age is 22

# %%
a=22
print('my age is',a and 'my name is hari')
# Out:
# my age is my name is hari

# %%
a='hari'
print('my name ia',a,'my age is 27')
# Out:
# my name ia hari my age is 27

# %%
course='data science'
time=6
duration=1.40
print('i am learning',course,'study in vt for',time,'months with',duration,'hour duration daliy')
# Out:
# i am learning data science study in vt for 6 months with 1.4 hour duration daliy

# %%
a=23
print('my name is hari and my age is '+str(a))
# Out:
# my name is hari and my age is 23

# %%
course='data science'
time=6
duration=1
print('i am learning '+course+' study in vt for '+str(time)+' months with '+str(duration)+' hour duration daliy')
# Out:
# i am learning data science study in vt for 6 months with 1 hour duration daliy

# %%
f=24
print('my name is hari and my age is %d' %(f))
# Out:
# my name is hari and my age is 24

# %%
course='data science'
time=6
duration=1
print('i am learning %s study in vt for %d months with %f hour duration daliy'%(course,time,duration))
# Out:
# i am learning data science study in vt for 6 months with 1.000000 hour duration daliy

# %%
f=45
print(f'my name is hari and my age is {f}')
# Out:
# my name is hari and my age is 45

# %%
a=20
b=30
print(f'value of a is {a} &value of b is {b} & there sum is:{a+b}')
# Out:
# value of a is 20 &value of b is 30 & there sum is:50
