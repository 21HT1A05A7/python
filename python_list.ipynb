# %%
a=[1,20,30,40]
print(a)
# Out:
# [1, 20, 30, 40]

# %%
a='data'
b=[10,20,30,40]
print(a[2])
print(b[1])
# Out:
# t
# 20

# %%
a=[10,20,30,40,50,80,90]
a[5]=60
print(a)
# Out:
# [10, 20, 30, 40, 50, 60, 90]

# %%
a=[10,20,30,40]
a.append(50)
print(a)
# Out:
# [10, 20, 30, 40, 50]

# %%
a=[10,20,30,40,50]
a.extend([60])
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a=[20,30,40,50]
a.insert(2,56)
print(a)
# Out:
# [20, 30, 56, 40, 50]

# %%
a=[10,20,30,40,50]
a.pop()
print(a)
# Out:
# [10, 20, 30, 40]

# %%
a=[10,20,30,40,50]
a.pop(3)
print(a)
# Out:
# [10, 20, 30, 50]

# %%
a=[10,20,30,40,50]
a.remove(40)
print(a)
# Out:
# [10, 20, 30, 50]

# %%
a=[10,20,30,40,30]
a.count(30)
# Out:
# 2

# %%
a=[10,20,30,40,30]
print(a.index(30,3))
# Out:
# 4

# %%
a=[10,20,30,40]
a.reverse()
print(a)
# Out:
# [40, 30, 20, 10]

# %%
a=[20,1,30,40,2,4,5,6]
a.sort()
print(a)
# Out:
# [1, 2, 4, 5, 6, 20, 30, 40]

# %%
a=[10,20,30,40,50]
a.clear()
print(a)
# Out:
# []

# %%
a=[10,20,30,40,50]
b=a
print(a)
print(b)
print(id(a))
print(id(b))
a.append(60)
print(a)
print(b)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# 134804033153152
# 134804033153152
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
