# %%
try:
 a=10
 b=20
 print(b/a)
except exception as e:
  print(e)
# Out:
# 2.0

# %%
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
   print(e)
# Out:
# division by zero

# %%
from os import name
try:
  a=10
  b=0
  print(a/b)
except ValueError as e:
  print(e)
except NameError as e:
  print(e)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3761965078.py in <cell line: 0>()
#       3   a=10
#       4   b=0
# ----> 5   print(a/b)
#       6 except ValueError as e:
#       7   print(e)
#
# ZeroDivisionError: division by zero

# %%
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
   print(e)
finally:
  print('i will the run with error')
# Out:
# division by zero
# i will the run with error

# %%
try:
  a=10
  b=20
  print(a/b)
except Exception as e:
  print(e)
finally:
  print('i will the run without error')
# Out:
# 0.5
# i will the run without error

# %%
import os
import sys

# %%
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
  print(f'error msg given by try block:{e}')
  sys.exc_info()
# Out:
# error msg given by try block:division by zero

# %%
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
  print(f'error msg given by try block:{e}')
  error_type,error_msg,error_line = sys.exc_info()
  print(f'error type:{error_type}')
  print(f'error message by sys:{error_msg}')
  print(f'error lineno:{error_line.tb_lineno}')
# Out:
# error msg given by try block:division by zero
# error type:<class 'ZeroDivisionError'>
# error message by sys:division by zero
# error lineno:4

# %%
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
  error_type,error_msg,error_line = sys.exc_info()
  print(f'error in lineno:{error_line.tb_lineno}:due to:{error_type}:reason:{error_msg}')
# Out:
# error in lineno:4:due to:<class 'ZeroDivisionError'>:reason:division by zero

# %%
print'sum')
# Out:
#   File "/tmp/ipython-input-3620011628.py", line 1
#     print'sum')
#               ^
# SyntaxError: unmatched ')'

# %%
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-302864193.py in <cell line: 0>()
# ----> 1 print(num)
#
# NameError: name 'num' is not defined

# %%
a=[1,2,3,4]
print(a[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-4043147931.py in <cell line: 0>()
#       1 a=[1,2,3,4]
# ----> 2 print(a[10])
#
# IndexError: list index out of range

# %%
a={1:'a',2:'b',3:'c'}
print(a[4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1897451308.py in <cell line: 0>()
#       1 a={1:'a',2:'b',3:'c'}
# ----> 2 print(a[4])
#
# KeyError: 4

# %%
if 4<3:
print('4 is greater than 3')
# Out:
#   File "/tmp/ipython-input-3770489221.py", line 2
#     print('4 is greater than 3')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1
