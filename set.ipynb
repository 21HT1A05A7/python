# %%
f={10,28.8,'data',(1,2,3)}
print(f)
# Out:
# {10, (1, 2, 3), 28.8, 'data'}

# %%
f={10,23.5,'string',(1,2)}
print(f)
# Out:
# {10, 'string', (1, 2), 23.5}

# %%
f={10,0,9,19}
f.add(100)
print(f)
# Out:
# {0, 100, 9, 10, 19}

# %%
f={10,20,30}
f.update([200,300,400])
print(f)
# Out:
# {200, 10, 300, 400, 20, 30}

# %%
f={10,20,30,40}
f.pop()
print(f)
# Out:
# {10, 20, 30}

# %%
f={10,20,30,50}
f.remove(20)
print(f)
# Out:
# {10, 50, 30}

# %%
f={10,20,30,50}
f.remove(100)
print(f)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1905708481.py in <cell line: 0>()
#       1 f={10,20,30,50}
# ----> 2 f.remove(100)
#       3 print(f)
#
# KeyError: 100

# %%
f={10,20,30,40}
f.discard(40)
print(f)
# Out:
# {10, 20, 30}

# %%
f={10,20,30,40}
f.discard(100)
print(f)
# Out:
# {40, 10, 20, 30}

# %%
f={10,20,30,40,50}
f.clear()
print(f)
# Out:
# set()

# %%
f={10,20,30,40,50}
f.copy()
print(f)
# Out:
# {50, 20, 40, 10, 30}

# %%
a={10,20,30,40}
b=a
print(a)
print(b)
print(id(a))
print(id(b))
a.add(100)
print(a)
print(b)
# Out:
# {40, 10, 20, 30}
# {40, 10, 20, 30}
# 139666369699552
# 139666369699552
# {100, 40, 10, 20, 30}
# {100, 40, 10, 20, 30}

# %%
a={10,20,30,40}
b=a.copy()
print(a)
print(b)
print(id(a))
print(id(b))
a.add(100)
print(a)
print(b)
# Out:
# {40, 10, 20, 30}
# {40, 10, 20, 30}
# 139666369702240
# 139666369695744
# {100, 40, 10, 20, 30}
# {40, 10, 20, 30}

# %%
a={10,20,30,40}
b={40,50,60,70}
c=a.union(b)
print(c)
# Out:
# {70, 40, 10, 50, 20, 60, 30}

# %%
a={10,20,30,40}
b={40,50,60,70}
c=a.intersection(b)
print(c)
# Out:
# {40}

# %%
a={10,20,30,40,50}
print(len(a))
# Out:
# 5

# %%
a={'abc',10,True,40,'ram'}
print(a)
# Out:
# {'abc', True, 'ram', 40, 10}

# %%
a={'abc','ram','naga'}
print(type(a))
# Out:
# <class 'set'>

# %%
a=set((1,2,3))
print(a)
# Out:
# {1, 2, 3}

# %%
a={'abc','ram','hari'}
for x in a:
  print(x)
# Out:
# abc
# hari
# ram

# %%
a={'banana','apple'}
print('banana' in a)
# Out:
# True

# %%
a={'apple','banana'}
b={23,45.6,'string'}
a.update(b)
print(a)
# Out:
# {'apple', 23, 'banana', 'string', 45.6}

# %%
a={'banana','apple','orange'}
b={'mango','carrot'}
a.update(b)
print(a)
# Out:
# {'apple', 'orange', 'banana', 'mango', 'carrot'}

# %%
a={'apple','banana','cherry'}
x=a.pop()
print(x)
print(a)
# Out:
# banana
# {'apple', 'cherry'}
