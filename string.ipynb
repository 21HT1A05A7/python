# %%
a='data science'
a=a.capitalize()
print(a)
# Out:
# Data science

# %%
a='data science'
print(a.capitalize())
# Out:
# Data science

# %%
a='computer science'
a=a.title()
print(a)
# Out:
# Computer Science

# %%
a='coMPUTER scIENce'
a=a.lower()
print(a)
# Out:
# computer science

# %%
a='DATA science'
a=a.upper()
print(a)
# Out:
# DATA SCIENCE

# %%
a='DATA  SCIENCE'
a=a.isupper()
print(a)
# Out:
# True

# %%
a='data science'
a=a.islower()
print(a)
# Out:
# True

# %%
a='data science'
print(a.islower())
# Out:
# True

# %%
a="nagalakshmi"
a=a.isalpha()
print(a)
# Out:
# True

# %%
a="naga123"
print(a.isalpha())
# Out:
# False

# %%
a='12345'
print(a.isnumeric())
# Out:
# True

# %%
a='naga123'
print(a.isnumeric())
# Out:
# False

# %%
d='data1234'
print(d.isalnum())
# Out:
# True

# %%
a='nagalakshmi'
print(a.startswith('l'))
# Out:
# False

# %%
a='data science'
print(a.endswith('i'))
# Out:
# False

# %%
a='computer science'
print(a.startswith('c'))
# Out:
# True

# %%
print(a.endswith('e'))
# Out:
# True

# %%
a='computer science'
print(a.replace('e','p'))
# Out:
# computpr scipncp

# %%
a='data science vihara'
end=a[a.index('a',16):]
start=a[:a.index('a',16)]
end=end.replace('a','p')
print(start+end)
# Out:
# data science vihprp

# %%
a='data science'
a.count('t')
# Out:
# 1

# %%
f="i love programming language"
print('love' in f)
# Out:
# True

# %%
python='df'
java='AB'
print(python<java)
# Out:
# False

# %%
ord('t')
# Out:
# 116

# %%
chr(2)
