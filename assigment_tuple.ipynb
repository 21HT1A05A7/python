# %%
Create an empty tuple.

# %%
a=()
print(a)
# Out:
# ()

# %%
Create a tuple with 5 integers.

# %%
a=(10,20,30,40,50)
print(a)
# Out:
# (10, 20, 30, 40, 50)

# %%
Access 3rd element of a tup
# Out:
#   File "/tmp/ipython-input-2020648552.py", line 1
#     Access 3rd element of a tuple.
#            ^
# SyntaxError: invalid decimal literal

# %%
a=(10,20,30,40)
b=a[3]
print(b)
# Out:
# 40

# %%
Access last element without negative index.

# %%
a=(10,20,30,40,50)
print(a[-1])
# Out:
# 50

# %%
Slice first three elements.

# %%
a=(10,20,30,40,50)
print(a[:3])
# Out:
# (10, 20, 30)

# %%
Slice every alternate value.

# %%
a=(10,20,39,40)
print(a[::2])
# Out:
# (10, 39)

# %%
Reverse a tuple using slicing.

# %%
a=(10,20,30,40,50)
print(a[::-1])
# Out:
# (50, 40, 30, 20, 10)

# %%
a=(1,2,3,4)
b=(5,6,7,8)
c=a+b
print(c)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
Replicate tuple (1,2) twice.

# %%
a=(1,2)
b=a*2
print(b)
# Out:
# (1, 2, 1, 2)

# %%
Find length of a tuple.

# %%
a=(1,2,3,4,5,6)
print(len(a))
# Out:
# 6

# %%
Convert a list to a tuple.

# %%
a=[1,2,3,4]
b=tuple(a)
print(b)
# Out:
# (1, 2, 3, 4)

# %%
Convert a string "python" to tuple of characters.

# %%
a="python"
b=tuple(a)
print(b)
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
Check if value exists in tuple.

# %%
a=(10,20,40,50,60)
b=30 in a
print(b)
# Out:
# False

# %%
Find maximum element in tuple.
# Out:
#   File "/tmp/ipython-input-3487149705.py", line 1
#     Find maximum element in tuple.
#          ^
# SyntaxError: invalid syntax

# %%
a=(10,2,4,5,7)
print(max(a))
# Out:
# 10

# %%
Find minimum element in tuple.

# %%
a=(12,3,4,5,6,9)
print(min(a))
# Out:
# 3

# %%
Count how many times 2 appears in (1,2,2,3).

# %%
a=(1,2,2,3)
a.count(2)
# Out:
# 2

# %%
Find index of an element.

# %%
a=(1,2,3,4,5)
print(a.index(5))
# Out:
# 4

# %%
Perform tuple packing.

# %%
a='naga',21,15000
print(a)
# Out:
# ('naga', 21, 15000)

# %%
perform tuple unpacking into variables.

# %%
name,age,salary=a
print(name)
print(age)
print(salary)
# Out:
# naga
# 21
# 15000

# %%
Convert tuple to string without loops.

# %%
a=('d','a','t','a')
b=''.join(a)
print(b)
# Out:
# data

# %%
b.immutable
c.a=(1,2,3)
b.t=(5)->integer
b.t=(1,)
b. As object references
b.20
c.last element
b.(2,3)
c. (1,3)
b.no
c.3
c. index()
b.8
c.2
c. 6
a. +
b. (1,2,1,2)
c. in
c. ("a","b","c")
b. ("b","c")
b. Counts frequency of element
b. sorted()
c. 3
b. 2
a. Storing items as tuple
a. Splitting tuple values into variables
a. tuple()
b. reversed object
a. Yes
a. Tuple
