# %% [markdown]
# Create a set with five numbers.

# %%
s={10,20,30,40,50}
print(s)
# Out:
# {50, 20, 40, 10, 30}

# %% [markdown]
# Add an element to a set.

# %%
s={10,20,30,40,50}
s.add(60)
print(s)
# Out:
# {50, 20, 40, 10, 60, 30}

# %% [markdown]
# Remove an element from a set if presen

# %%
a={10,30,40,50}
a.remove(30)
print(a)
# Out:
# {40, 10, 50}

# %% [markdown]
# Convert a list into a set.

# %%
a=[20,30,49,60]
b=set(a)
print(b)
# Out:
# {49, 20, 30, 60}

# %% [markdown]
# Check if an element exists in a set.

# %%
a={10,20,30,40}
b.discard(20)
print(b)
print(a)
# Out:
# {49, 30, 60}
# {40, 10, 20, 30}

# %% [markdown]
# Find union of two sets.

# %%
a={10,20,30,40,50}
b={30,40,50,60,70}
print(a.union(b))
# Out:
# {70, 40, 10, 50, 20, 60, 30}

# %% [markdown]
# Find intersection of two sets.

# %%
a={1,2,3,4,5,6}
b={5,6,7,8,9,10}
print(a.intersection(b))
# Out:
# {5, 6}

# %% [markdown]
# :Find difference between two sets.

# %%
a={1,2,3,4,5}
b={3,4,6,7,8}
c=a.difference(b)
print(c)
# Out:
# {1, 2, 5}

# %% [markdown]
# Find symmetric difference between two sets.

# %%
a={2,3,4,5,6,7}
b={6,7,8,9,10}
c=a.symmetric_difference(b)
print(c)
# Out:
# {2, 3, 4, 5, 8, 9, 10}

# %% [markdown]
# Remove all elements from a set.

# %%
a={10,20,30,40,50}
a.clear()
print(a)
# Out:
# set()

# %% [markdown]
# Create a frozen set from a list.

# %%
a={1,2,3,4,5}
b=frozenset(a)
print(b)
# Out:
# frozenset({1, 2, 3, 4, 5})

# %% [markdown]
# Convert a string into a set of characters.

# %%
a='data science'
b=set(a)
print(b)
# Out:
# {'n', 's', 'i', 'd', 'a', 'c', 'e', 't', ' '}

# %% [markdown]
# Check if one set is subset of another

# %%
a={7,8}
b={5,6,7,8,9}
print(a.issubset(b))
# Out:
# True

# %% [markdown]
# Check if one set is superset of another.

# %%
a={1,2,3,4,5,6}
b={1,2,3}
print(a.issuperset(b))
# Out:
# True

# %% [markdown]
# Check if two sets are disjoint.

# %%
a={1,2,3,4,5}
b={6,7,8,9}
print(a.isdisjoint(b))
# Out:
# True

# %% [markdown]
# Find length of a set.

# %%
a={10,20,30,40,50}
print(len(a))
# Out:
# 5

# %% [markdown]
# Pop an element from set and display result.

# %%
a={1,2,3,4,5,6,7}
a.pop()
print(a)
# Out:
# {2, 3, 4, 5, 6, 7}

# %% [markdown]
# Copy a set into another set variable.

# %%
a={10,20,30,40}
b=a
print(a)
print(b)
print(id(a))
print(id(b))
a.add(500)
print(a)
print(b)
# Out:
# {40, 10, 20, 30}
# {40, 10, 20, 30}
# 137193420140864
# 137193420140864
# {40, 10, 20, 500, 30}
# {40, 10, 20, 500, 30}

# %% [markdown]
# Create a set from a tuple.

# %%
a={1,2,3,4,5}
b=tuple(a)
print(b)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# Create two sets and show elements unique to each (symmetric diff).

# %%
a={1,2,3,4,5}
b={5,6,7,8,9}
unique_element=a.symmetric_difference(b)
print(unique_element)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}
