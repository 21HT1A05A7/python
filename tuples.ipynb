# %%
a=10,20,30
print(a)
print(type(a))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
a=(10,20,30,40)
print(a[1])
print(a[2])
print(a[3])
print(a[-1])
print(a[-2])
print(a[-3])
# Out:
# 20
# 30
# 40
# 40
# 30
# 20

# %%
a=(10,20,30)
b=(1,2,3,4)
c=b+a
print(c)
# Out:
# (1, 2, 3, 4, 10, 20, 30)

# %%
a=(10,20,30,40)
b=a*3
print(b)
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40, 10, 20, 30, 40)

# %%
a=(1,2)*2
print(a)
# Out:
# (1, 2, 1, 2)

# %%
a=("abc")
print(a)
# Out:
# abc
