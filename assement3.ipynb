# %%
Which of the following is a valid variable name in Python?
a) 1variable
b) variable_1
c) variable-1
d) variable one

# %%
b. variable_1

# %%
print(type(0.5))
# Out:
# <class 'float'>

# %%
Which operator is used for exponentiation in Python?
a) ^
b) **
c) *
d) //

# %%
**

# %%
10//3
# Out:
# 3

# %%
Which function converts a string to an integer?
a) str()
b) int()
c) eval()
d) type()

# %%
int()

# %%
Strings in Python are:
a) Mutable
b) Immutable
c) Dynamic
d) Static

# %%
immutable

# %%
print('abc'+'123')
# Out:
# abc123

# %%
 Which method returns the length of a string?
a) count()
b) size()
c) len()
d) length()

# %%
len()

# %%
print('python'.upper())
# Out:
# PYTHON

# %%
What is the default return type of input() function?
a) int
b) str
c) float
d) bool

# %%
str

# %%
Which of the following represents a complex number?
a) 4.5
b) 2 + 3j
c) '4.5'
d) 2j3

# %%
2+3j

# %%
What does '==' operator check?

# %%
equallity

# %%
 Which of the following is NOT a data type in Python?
a) list
b) tuple
c) integer
d) array

# %%
array

# %%
Which function gives the memory address of an object?
a) id()
b) memory()
c) ref()
d) type()

# %%
id()

# %%
What is slicing in Python?
a) Dividing lists
b) Extracting part of a sequence
c) Adding elements
d) Removing elements

# %%
extracting part of a sequence

# %%
print(bool(''))
# Out:
# False

# %%
 Which operator is used to check identity?
a) ==
b) is
c) in
d) not

# %%
is

# %%
print(5+True)
# Out:
# 6

# %%
Which function gives the data type of a variable?
a) datatype()
b) typeof()
c) type()
d) id()

# %%
type()

# %%
a='python'
a[2:5]
# Out:
# 'tho'

# %%
Which of the following converts an integer to string?
a) str()
b) int()
c) chr()
d) repr()

# %%
str()

# %%
print('hello'*3)
# Out:
# hellohellohello

# %%
hich method removes spaces from both ends of a string?
a) trim()
b) remove()
c) strip()
d) slice()

# %%
strip

# %%
print('python'.find('t'))
# Out:
# 2

# %%
Which function can be used to convert any value into a string representation?
a) format()
b) str()
c) toString()
d) parse()

# %%
str()

# %%
Write a Python program to swap two variables without using a third variable.

# %%
a=23
b=33
a,b=b,a
print(a)
print(b)
# Out:
# 33
# 23

# %%
Write a program to check whether a number is even or odd.

# %%
a=23
if a%2 == 0:
  print(a,'even')
else:
  print(a,'odd')
# Out:
# 23 odd

# %%
Write a program to take two numbers and display the larger one.

# %%
a=12
b=15
if a>b:
  print("The largest number is:",a)
else:
  print("The largest number is:",b)
# Out:
# The largest number is: 15

# %%
Create a program to reverse a given string using slicing.

# %%
a='data science'
reversed_a=a[::-1]
print("reversed string:",reversed_a)
# Out:
# reversed string: ecneics atad

# %%
Write a program that reads a number and prints its multiplication table.

# %%
num = int(input("Enter a number: "))

print("Multiplication Table of", num)
for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter a number: 7
# Multiplication Table of 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
Write a Python program to check whether a character is alphabet, digit, or special character.

# %%
ch = input("Enter a character: ")

if ch.isalpha():
    print("It is an Alphabet.")
elif ch.isdigit():
    print("It is a Digit.")
else:
    print("It is a Special Character.")
# Out:
# Enter a character: '1234'
# It is a Special Character.

# %%
Write a program to count the number of words in a string.

# %%
text = input("Enter a string: ")

words = text.split()
print("Number of words:", len(words))
# Out:
# Enter a string: 'data science'
# Number of words: 2
